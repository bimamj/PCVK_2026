# %% [markdown]
# <a href="https://colab.research.google.com/github/bimamj/PCVK_2026/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg","https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg","https://i.pinimg.com/736x/23/03/0e/23030e5d5a88da8171684365cca2482d.jpg"]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')

tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("Resolusi image: tinggi x lebar = ",tinggi, " x ",lebar)
cv2_imshow(image_2)

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
for y in range (lebar):
  image_3[int((tinggi)/2), y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=736x460>
# Resolusi image: tinggi x lebar =  460  x  368
# <PIL.Image.Image image mode=RGB size=368x460>
# <PIL.Image.Image image mode=RGB size=736x460>

# %% [markdown]
# Practicum D2 Answers
# 1. Because Google Colab is free cloud based and can be used without installation. Colab also provide GPU access so that we can do Machine learning and Computer vision experiment without expensive hardware
# 2. Numpy is an array manipulation library, pandas is a library for data manipulation and data analysis, CV2 is a library for computer vision task and Matlplotlib is a library which generates figures and provides graphical user interface toolkit. We only used skimage and cv2
# 3. If we dont use that code the image size will be too big, so we need to resize it
# 4. The code [255,255,255] is to set the color to white for the line
# 5. Pixel is the smallest unit in digital image use to represent visual object in numerical form. The characteristic of digital vision/image is determined by resolution (horizontal pixel x vertical pixel)

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

image = io.imread("https://i.pinimg.com/736x/23/03/0e/23030e5d5a88da8171684365cca2482d.jpg")
image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("Resolusi image: tinggi x lebar = ",tinggi, " x ",lebar)
# middle vertical line
# for x in range (tinggi):
#   image_3[x, int((lebar)/2)] = [255, 255, 255]
# diagonal cross
# for row in range(tinggi):
#   col1 = int(row * (lebar / tinggi))
#   col2 = int((lebar - 1) - (row * (lebar / tinggi)))
#   if col1 < lebar:
#     image_3[row, col1] = [255, 255, 255]
#   if col2 >= 0:
#     image_3[row, col2] = [255, 255, 255]
# certain length line
# cy = tinggi // 2
# start_x = 50
# end_x = 250
# for x in range(start_x, end_x):
#   if x < lebar:
#     image_3[cy, x] = [255, 255, 255]
# square
sisi = 100
start_x = (lebar // 2) - (sisi // 2)
start_y = (tinggi // 2) - (sisi // 2)
end_x = start_x + sisi
end_y = start_y + sisi

# loop tiap y tinggi kotak
for y in range(start_y, end_y):
    # loop tiap x lebar kotak
    for x in range(start_x, end_x):
      image_3[y, x] = [255, 255, 255]  # Fill pixel with white
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# Resolusi image: tinggi x lebar =  460  x  368
# <PIL.Image.Image image mode=RGB size=736x460>

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

img = cv2.imread("/content/drive/MyDrive/PCVK/Ktm bima.jpg")
# img_2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# plt.imshow(img_2)

# img_gray = cv2.imread("/content/drive/MyDrive/PCVK/Ktm bima.jpg", cv2.IMREAD_GRAYSCALE)

# # Tanpa cmap
# plt.subplot(1,2,1)
# plt.imshow(img_gray)
# plt.title("Tanpa cmap")

# # Tanpa cmap
# plt.subplot(1,2,2)
# plt.imshow(img_gray, cmap="gray")
# plt.title("Dengan cmap")

# plt.show()

# plt.imshow(img_gray, cmap="magma")

imgRGB=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imgRGBsmall=cv2.resize(imgRGB,(400,250))
imgBalik=cv2.flip(imgRGBsmall, 1)

#tampilkan ukuran canvas yang lebih besar
# fig=plt.figure(figsize=(10,10))
# ax=fig.add_subplot(111)
# plt.imshow(imgBalik)
# ax.imshow(imgBalik)

black_img = np.zeros(shape=(512,512,3),dtype=np.int16)

#koordinat pt1 pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
cv.circle(black_img,center=(400,400),radius=50,color=(255,0,0),thickness=-1)
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
# plt.imshow(black_img)

black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
pts = vertices.reshape((-1,1,2))
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# Practicum D3 Questions and answers
# 1. OpenCV use BGR format while matplotlib use RGB format. Displaying image using OpenCV without using Matplotlib conversion will result in wrong image color
# 2. int32 use 4 byte per pixel avlue while int16 use 2 byte, which means that int32 will use more memory space
# 3. It is used because google colab is cloud based and doesn't support external GUI, cv2_imshow is used to render and display image from OpenCv in notebook
# 4. It is to impor io module from Scikit-image library that is used to read, save and load image data
