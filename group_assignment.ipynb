# %% [markdown]
# <a href="https://colab.research.google.com/github/bimamj/PCVK_2026/blob/main/group_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
img = cv2.imread("/content/drive/MyDrive/PCVK/ktm_exc_scan.jpeg")
cv2.rectangle(img,pt1=(1560,30),pt2=(1100,200),color=(0,255,0),thickness=(10))
cv2.rectangle(img,pt1=(1570,550),pt2=(1280,840),color=(0,0,255),thickness=(15))
cv2.rectangle(img,pt1=(1130,48),pt2=(1260,175),color=(255,0,0),thickness=(5))
cv2.circle(img,center=(1502,35),radius=1,color=(255,0,0),thickness=(50))
cv2.line(img,pt1=(1130,115),pt2=(1260,115),color=(0,255,0),thickness=(10))
cv2.line(img,pt1=(1570,550),pt2=(1280,840),color=(255,255,0),thickness=(10))
cv2.line(img,pt1=(1280,550),pt2=(1570,840),color=(255,255,0),thickness=(10))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
